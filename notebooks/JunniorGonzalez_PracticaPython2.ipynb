# %% [markdown]
# # Práctica de Python y pandas
# **Asignatura:** Big Data
# **Modalidad de entrega:** Jupyter Notebook (.ipynb)
#
# ### Introducción
# En este notebook se resuelven los ejercicios asignados aplicando la sintaxis básica de Python: estructuras de control, ciclos y operaciones con cadenas de texto. Cada ejercicio incluye el enunciado, el código, el resultado y una explicación de la lógica utilizada. Los valores de entrada están definidos directamente en variables para facilitar la revisión sin necesidad de interacción del usuario.

# %% [markdown]
# ## Ejercicio 16: DataFrame de estudiantes
# **Enunciado:**
# - Cree un DataFrame con al menos 10 estudiantes.
# - Incluya nombre, carrera, edad, promedio y ciudad.
# - Muestre las primeras 5 filas.
# - Muestre la información general del DataFrame.
# - Calcule el promedio general de calificaciones.
# - Muestre estudiantes con promedio mayor o igual a 80.
# - Ordene estudiantes por promedio de mayor a menor.
#
# **Logica:**
# - `pd.DataFrame()` convierte un diccionario en una tabla organizada en filas y columnas.
# - `head()` muestra solo las primeras 5 filas, para revisar rápido cómo quedaron los datos.
# - `info()` muestra un resumen del DataFrame: cuántas filas hay, qué tipo de dato tiene cada columna y si hay valores vacíos.
# - `mean()` calcula el promedio de todos los valores de una columna.
# - `df[df["promedio"] >= 80]` filtra la tabla y muestra solo las filas que cumplen esa condición.
# - `sort_values()` ordena la tabla según una columna. Con `ascending=False` ordena de mayor a menor.

# %%
# Importamos pandas para poder usar DataFrames
import pandas as pd

# Creamos los datos de los estudiantes en un diccionario
datos = {
    "nombre":   ["Ana López", "Carlos Pérez", "María García", "José Martínez", "Laura Díaz",
                 "Pedro Ramírez", "Sofía Torres", "Luis Hernández", "Valeria Cruz", "Diego Flores"],
    "carrera":  ["Sistemas", "Contabilidad", "Derecho", "Medicina", "Sistemas",
                 "Derecho", "Medicina", "Contabilidad", "Sistemas", "Medicina"],
    "edad":     [20, 22, 21, 23, 20, 24, 21, 22, 20, 23],
    "promedio": [85, 72, 90, 65, 88, 78, 95, 70, 83, 60],
    "ciudad":   ["Tegucigalpa", "San Pedro Sula", "Tegucigalpa", "La Ceiba", "Comayagua",
                 "San Pedro Sula", "Tegucigalpa", "La Ceiba", "Comayagua", "Tegucigalpa"]
}

# Convertimos el diccionario en un DataFrame
df = pd.DataFrame(datos)

# Mostramos las primeras 5 filas
print("Primeras 5 filas:")
print(df.head())

# Mostramos la información general del DataFrame
print("\nInformación general:")
print(df.info())

# Calculamos el promedio general de todos los estudiantes
promedio_general = df["promedio"].mean()
print("\nPromedio general de calificaciones:", promedio_general)

# Mostramos solo los estudiantes con promedio mayor o igual a 80
print("\nEstudiantes con promedio mayor o igual a 80:")
print(df[df["promedio"] >= 80])

# Ordenamos de mayor a menor promedio
print("\nEstudiantes ordenados por promedio (mayor a menor):")
print(df.sort_values("promedio", ascending=False))
# Out:
# Primeras 5 filas:
#           nombre       carrera  edad  promedio          ciudad
# 0      Ana López      Sistemas    20        85     Tegucigalpa
# 1   Carlos Pérez  Contabilidad    22        72  San Pedro Sula
# 2   María García       Derecho    21        90     Tegucigalpa
# 3  José Martínez      Medicina    23        65        La Ceiba
# 4     Laura Díaz      Sistemas    20        88       Comayagua
#
# Información general:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    10 non-null     str
#  1   carrera   10 non-null     str
#  2   edad      10 non-null     int64
#  3   promedio  10 non-null     int64
#  4   ciudad    10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes
# None
#
# Promedio general de calificaciones: 78.6
#
# Estudiantes con promedio mayor o igual a 80:
# ...

# %% [markdown]
# ## Ejercicio 17: Análisis de ventas con pandas
# **Enunciado:**
# - Cree un DataFrame de ventas con al menos 15 registros.
# - Incluya fecha, vendedor, producto, categoría, cantidad y precio unitario.
# - Calcule una nueva columna TotalVenta.
# - Calcule el total vendido por vendedor.
# - Identifique el producto más vendido.
# - Identifique la categoría con mayor ingreso.
# - Ordene las ventas de mayor a menor.
#
# **Logica:**
# - pd.DataFrame(datos)  crea una tabla de datos usando pandas.
# - ventas["TotalVenta"] crea una nueva columna multiplicando cantidad por precio unitario.
# - groupby() agrupa datos por una columna.
# - sum() suma valores numéricos.
# - idxmax() devuelve el elemento con el valor máximo.
# - sort_values() ordena los datos.
# - ascending=False ordena de mayor a menor.

# %%
import pandas as pd

# Datos de ventas
datos = {
    "Fecha": [
        "2025-05-01","2025-05-02","2025-05-03","2025-05-04","2025-05-05",
        "2025-05-06","2025-05-07","2025-05-08","2025-05-09","2025-05-10",
        "2025-05-11","2025-05-12","2025-05-13","2025-05-14","2025-05-15"
    ],

    "Vendedor": [
        "Ana","Luis","Pedro","Ana","Luis",
        "Pedro","Ana","Luis","Pedro","Ana",
        "Luis","Pedro","Ana","Luis","Pedro"
    ],

    "Producto": [
        "Laptop","Mouse","Teclado","Monitor","Laptop",
        "Mouse","Teclado","Laptop","Monitor","Mouse",
        "Laptop","Teclado","Monitor","Mouse","Laptop"
    ],

    "Categoria": [
        "Tecnologia","Accesorios","Accesorios","Tecnologia","Tecnologia",
        "Accesorios","Accesorios","Tecnologia","Tecnologia","Accesorios",
        "Tecnologia","Accesorios","Tecnologia","Accesorios","Tecnologia"
    ],

    "Cantidad": [
        2,5,3,1,2,
        4,2,1,2,3,
        2,4,1,6,3
    ],

    "PrecioUnitario": [
        800,20,35,250,800,
        20,35,800,250,20,
        800,35,250,20,800
    ]
}

# Crear DataFrame
ventas = pd.DataFrame(datos)

# Nueva columna TotalVenta
ventas["TotalVenta"] = ventas["Cantidad"] * ventas["PrecioUnitario"]

print("DataFrame completo")
print(ventas)

# Total vendido por vendedor
total_vendedor = ventas.groupby("Vendedor")["TotalVenta"].sum()

print("\nTotal vendido por vendedor")
print(total_vendedor)

# Producto más vendido
producto_mas_vendido = ventas.groupby("Producto")["Cantidad"].sum()

print("\nProducto más vendido")
print(producto_mas_vendido.idxmax())

# Categoría con mayor ingreso
categoria_ingreso = ventas.groupby("Categoria")["TotalVenta"].sum()

print("\nCategoría con mayor ingreso")
print(categoria_ingreso.idxmax())

# Ordenar ventas
ventas_ordenadas = ventas.sort_values(
    by="TotalVenta",
    ascending=False
)

print("\nVentas ordenadas")
print(ventas_ordenadas)
# Out:
# DataFrame completo
#          Fecha Vendedor Producto   Categoria  Cantidad  PrecioUnitario  \
# 0   2025-05-01      Ana   Laptop  Tecnologia         2             800
# 1   2025-05-02     Luis    Mouse  Accesorios         5              20
# 2   2025-05-03    Pedro  Teclado  Accesorios         3              35
# 3   2025-05-04      Ana  Monitor  Tecnologia         1             250
# 4   2025-05-05     Luis   Laptop  Tecnologia         2             800
# 5   2025-05-06    Pedro    Mouse  Accesorios         4              20
# 6   2025-05-07      Ana  Teclado  Accesorios         2              35
# 7   2025-05-08     Luis   Laptop  Tecnologia         1             800
# 8   2025-05-09    Pedro  Monitor  Tecnologia         2             250
# 9   2025-05-10      Ana    Mouse  Accesorios         3              20
# 10  2025-05-11     Luis   Laptop  Tecnologia         2             800
# 11  2025-05-12    Pedro  Teclado  Accesorios         4              35
# ...

# %% [markdown]
# ## Ejercicio 18: Limpieza de datos con pandas
# **Enunciado:**
# - Cree un DataFrame con datos incompletos de clientes.
# - Incluya nombre, edad, correo, ciudad y teléfono.
# - Identifique valores nulos.
# - Cuente los valores nulos por columna.
# - Reemplace ciudades vacías con "No especificada".
# - Elimine registros que no tengan correo.
# - Muestre el DataFrame limpio.
#
# **Lógica:**
#
# Se usan listas y ciclos para revisar datos vacíos. Luego se reemplazan ciudades vacías y se eliminan clientes que no tienen correo.

# %%
clientes = [
    ["Ana", 22, "ana@gmail.com", "Tegucigalpa", "9999-1111"],
    ["Carlos", 35, "", "", "8888-2222"],
    ["María", "", "maria@gmail.com", "San Pedro Sula", ""],
    ["José", 28, "jose@gmail.com", "", "7777-3333"],
    ["Lucía", 40, "", "La Ceiba", "6666-4444"]
]

print("DATOS ORIGINALES")
for cliente in clientes:
    print(cliente)

# Contar valores vacíos
nulos = 0

for cliente in clientes:
    for dato in cliente:
        if dato == "":
            nulos += 1

print("\nCantidad de valores vacíos:", nulos)

# Reemplazar ciudades vacías
for cliente in clientes:
    if cliente[3] == "":
        cliente[3] = "No especificada"

# Eliminar clientes sin correo
clientes_limpios = []

for cliente in clientes:
    if cliente[2] != "":
        clientes_limpios.append(cliente)

print("\nDATOS LIMPIOS")

for cliente in clientes_limpios:
    print(cliente)
# Out:
# DATOS ORIGINALES
# ['Ana', 22, 'ana@gmail.com', 'Tegucigalpa', '9999-1111']
# ['Carlos', 35, '', '', '8888-2222']
# ['María', '', 'maria@gmail.com', 'San Pedro Sula', '']
# ['José', 28, 'jose@gmail.com', '', '7777-3333']
# ['Lucía', 40, '', 'La Ceiba', '6666-4444']
#
# Cantidad de valores vacíos: 6
#
# DATOS LIMPIOS
# ['Ana', 22, 'ana@gmail.com', 'Tegucigalpa', '9999-1111']
# ['María', '', 'maria@gmail.com', 'San Pedro Sula', '']
# ['José', 28, 'jose@gmail.com', 'No especificada', '7777-3333']

# %% [markdown]
# ## Ejercicio 19: Análisis de préstamos
# - Cree un DataFrame con solicitudes de préstamo.
# - Incluya cliente, monto solicitado, plazo, ingreso mensual y estado de solicitud.
# - Calcule el monto promedio solicitado.
# - Cuente solicitudes por estado.
# - Muestre únicamente préstamos aprobados.
# - Muestre clientes con monto solicitado mayor a 50,000.
# - Agrupe por estado y calcule el promedio del monto solicitado.
#
# **Lógica:**
#
# Se creó un DataFrame con información de solicitudes de préstamos. Luego se aplicaron funciones de pandas para analizar los datos: se calculó el promedio del monto solicitado con mean(), se contaron solicitudes por estado con value_counts(), se filtraron préstamos aprobados y montos mayores a 50,000, y se usó groupby() para obtener el promedio del monto por estado.

# %%
# Importamos pandas
import pandas as pd

# Datos de los prestamos
datos = {
    "cliente": ["Ana Lopez", "Carlos Perez", "Maria Gomez", "Jose Ruiz",
                "Lucia Torres", "Pedro Martinez", "Sofia Castro", "Luis Herrera"],

    "monto_solicitado": [45000, 60000, 30000, 80000,
                         52000, 47000, 90000, 25000],

    "plazo": [12, 24, 18, 36, 24, 12, 48, 6],

    "ingreso_mensual": [15000, 25000, 12000, 40000,
                        22000, 18000, 50000, 10000],

    "estado": ["Aprobado", "Pendiente", "Rechazado", "Aprobado",
               "Aprobado", "Pendiente", "Aprobado", "Rechazado"]
} 

# Crear el DataFrame
df = pd.DataFrame(datos)

# Mostrar las primeras filas
print("Primeras 5 filas:")
print(df.head())

# Informacion general
print("\nInformacion general:")
print(df.info())

# Promedio del monto solicitado
promedio = df["monto_solicitado"].mean()

print("\nPromedio del monto solicitado:", promedio)

# Cantidad de solicitudes por estado
print("\nSolicitudes por estado:")
print(df["estado"].value_counts())

# Solo prestamos aprobados
print("\nPrestamos aprobados:")
print(df[df["estado"] == "Aprobado"])

# Clientes con monto mayor a 50000
print("\nClientes con monto mayor a 50000:")
print(df[df["monto_solicitado"] > 50000])

# Agrupar por estado y sacar promedio
print("\nPromedio por estado:")
print(df.groupby("estado")["monto_solicitado"].mean())
# Out:
# Primeras 5 filas:
#         cliente  monto_solicitado  plazo  ingreso_mensual     estado
# 0     Ana Lopez             45000     12            15000   Aprobado
# 1  Carlos Perez             60000     24            25000  Pendiente
# 2   Maria Gomez             30000     18            12000  Rechazado
# 3     Jose Ruiz             80000     36            40000   Aprobado
# 4  Lucia Torres             52000     24            22000   Aprobado
#
# Informacion general:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cliente           8 non-null      str
#  1   monto_solicitado  8 non-null      int64
#  2   plazo             8 non-null      int64
#  3   ingreso_mensual   8 non-null      int64
#  4   estado            8 non-null      str
# dtypes: int64(3), str(2)
# memory usage: 452.0 bytes
# None
#
# Promedio del monto solicitado: 53625.0
#
# ...

# %% [markdown]
# ## Ejercicio 20: Mini análisis de datos tipo empresa
# - Cree un DataFrame con información de empleados.
# - Incluya nombre, departamento, cargo, salario, años de experiencia y ciudad.
# - Muestre los primeros registros.
# - Muestre estadísticas generales de salarios.
# - Calcule el salario promedio por departamento.
# - Encuentre el empleado con salario más alto.
# - Muestre empleados con más de 5 años de experiencia.
# - Ordene empleados por salario.
# - Cree una columna NivelExperiencia: Junior, Intermedio o Senior.
#
# **Lógica:**
#
# Se creó un DataFrame con información de empleados. Luego se usó pandas para mostrar registros, obtener estadísticas de salario, calcular promedios por departamento, encontrar el salario más alto, filtrar empleados con experiencia mayor a 5 años, ordenar salarios y crear una clasificación automática del nivel de experiencia mediante una función.

# %%
import pandas as pd

# Crear datos de empleados

datos = {
    "Nombre": [
        "Ana","Luis","Pedro","Maria","Carlos",
        "Sofia","Jorge","Elena","Miguel","Laura"
    ],

    "Departamento": [
        "TI","Ventas","RRHH","TI","Ventas",
        "Finanzas","TI","RRHH","Ventas","Finanzas"
    ],

    "Cargo": [
        "Programador","Vendedor","Analista","Desarrollador",
        "Supervisor","Contador","Soporte",
        "Reclutador","Vendedor",
        "Analista Financiero"
    ],

    "Salario": [
        1200,900,850,1400,1100,
        1300,1000,950,850,1500
    ],

    "Experiencia": [
        2,6,4,8,10,
        7,3,5,1,12
    ],

    "Ciudad": [
        "Managua","Leon","Esteli","Managua","Chinandega",
        "Leon","Esteli","Managua","Leon","Granada"
    ]
}

# Crear DataFrame

empleados = pd.DataFrame(datos)

# Mostrar primeros registros

print("Primeros registros")

print(empleados.head())

# Estadísticas de salarios

print("\nEstadísticas generales de salarios")

print(empleados["Salario"].describe())

# Promedio de salario por departamento

promedio_departamento = empleados.groupby(
    "Departamento"
)["Salario"].mean()

print("\nSalario promedio por departamento")

print(promedio_departamento)

# Empleado con salario más alto

empleado_mayor_salario = empleados.loc[
    empleados["Salario"].idxmax()
]

print("\nEmpleado con salario más alto")

print(empleado_mayor_salario)

# Empleados con más de 5 años de experiencia

mayor_experiencia = empleados[
    empleados["Experiencia"] > 5
]

print("\nEmpleados con más de 5 años de experiencia")

print(mayor_experiencia)

# Ordenar empleados por salario

empleados_ordenados = empleados.sort_values(
    by="Salario",
    ascending=False
)

print("\nEmpleados ordenados por salario")

print(empleados_ordenados)

# Crear columna NivelExperiencia

def clasificar_experiencia(anios):

    if anios <= 2:
        return "Junior"

    elif anios <= 5:
        return "Intermedio"

    else:
        return "Senior"

empleados["NivelExperiencia"] = empleados[
    "Experiencia"
].apply(clasificar_experiencia)

print("\nDataFrame final")

print(empleados)
# Out:
# Primeros registros
#    Nombre Departamento          Cargo  Salario  Experiencia      Ciudad
# 0     Ana           TI    Programador     1200            2     Managua
# 1    Luis       Ventas       Vendedor      900            6        Leon
# 2   Pedro         RRHH       Analista      850            4      Esteli
# 3   Maria           TI  Desarrollador     1400            8     Managua
# 4  Carlos       Ventas     Supervisor     1100           10  Chinandega
#
# Estadísticas generales de salarios
# count      10.000000
# mean     1105.000000
# std       235.053185
# min       850.000000
# 25%       912.500000
# 50%      1050.000000
# 75%      1275.000000
# max      1500.000000
# Name: Salario, dtype: float64
#
# Salario promedio por departamento
# Departamento
# Finanzas    1400.0
# RRHH         900.0
# TI          1200.0
# Ventas       950.0
# Name: Salario, dtype: float64
#
# Empleado con salario más alto
# Nombre                        Laura
# Departamento               Finanzas
# ...
